# %%
# %matplotlib inline

# %%
import pandas as pd

solution_pandas_df = pd.read_csv(
    'solution_pandas.dat', sep=' ', usecols=[1])

solution_pandas_df['elapsed_secs'] = solution_pandas_df.index / 10
solution_pandas_df.rename(columns={'python': 'solution_pandas_mb_used'})


solution_pandas_df.head()
# Out:
#       python
# 0   1.101562
# 1   9.910156
# 2  16.554688
# 3  27.199219
# 4  31.437500

# %%
solution_pandas_df
# Out:
#          python  elapsed  elapsed_secs
# 0      1.101562      0.0           0.0
# 1      9.910156      0.1           0.1
# 2     16.554688      0.2           0.2
# 3     27.199219      0.3           0.3
# 4     31.437500      0.4           0.4
# ...         ...      ...           ...
# 1978   0.000000    197.8         197.8
# 1979   0.000000    197.9         197.9
# 1980   0.000000    198.0         198.0
# 1981   0.000000    198.1         198.1
# 1982   0.000000    198.2         198.2
#
# [1983 rows x 3 columns]

# %%
solution_pandas_df.plot(x='elapsed_secs', y='python')
# Out:
# <AxesSubplot:xlabel='elapsed_secs'>
